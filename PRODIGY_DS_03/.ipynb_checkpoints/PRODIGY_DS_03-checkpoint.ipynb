# %%
# Build a decision tree classifier to predict whether a customer will purchase a product or service based on their demographic and behavioral data. Use a dataset such as the Bank Marketing dataset from the UCI Machine Learning Repository.
# Sample Dateset :- https://archive.ics.uci.edu/ml/datasets/Bank+Marketing

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# !pip install ucimlrepo

# %%
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
bank_marketing = fetch_ucirepo(id=222)

# %%
bank_marketing.keys()
# Out:
# dict_keys(['data', 'metadata', 'variables'])

# %%
bank_marketing['data'].keys()
# Out:
# dict_keys(['ids', 'features', 'targets', 'original', 'headers'])

# %%
df = bank_marketing['data']['original']
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married        NaN      no     1506     yes   no
# 4       33           NaN    single        NaN      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df.isnull().sum()
# Out:
# age                0
# job              288
# marital            0
# education       1857
# default            0
# balance            0
# housing            0
# loan               0
# contact        13020
# day_of_week        0
# month              0
# duration           0
# campaign           0
# pdays              0
# previous           0
# poutcome       36959
# y                  0
# dtype: int64

# %%
len(df)
# Out:
# 45211

# %%
(df['education'].isnull().sum()/len(df))*100
# Out:
# 4.1074074893278185

# %%
df.drop(columns=['contact','poutcome'],inplace=True)

# %%
df.dropna(subset=['education'],inplace=True)

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 5       35    management   married   tertiary      no      231     yes   no
# 6       28    management    single   tertiary      no      447     yes  yes
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
df.isnull().sum()
# Out:
# age              0
# job            161
# marital          0
# education        0
# default          0
# balance          0
# housing          0
# loan             0
# day_of_week      0
# month            0
# duration         0
# campaign         0
# pdays            0
# previous         0
# y                0
# dtype: int64

# %%
df.dropna(subset=['job'],inplace=True)
df.isnull().sum()
# Out:
# age            0
# job            0
# marital        0
# education      0
# default        0
# balance        0
# housing        0
# loan           0
# day_of_week    0
# month          0
# duration       0
# campaign       0
# pdays          0
# previous       0
# y              0
# dtype: int64

# %%
len(df)
# Out:
# 43193

# %%
(43193/45211)*100
# Out:
# 95.53648448386454

# %%
100-95.53648448386454
# Out:
# 4.463515516135459

# %%
# 4.46% Data lose happened in this filtering process

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       35    management   married   tertiary      no      231     yes   no
# 4       28    management    single   tertiary      no      447     yes  yes
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 43188   51    technician   married   tertiary      no      825      no   no
# 43189   71       retired  divorced    primary      no     1729      no   no
# 43190   72       retired   married  secondary      no     5715      no   no
# 43191   57   blue-collar   married  secondary      no      668      no   no
# 43192   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
print("Unique Marital values",df['marital'].unique())
print("Unique Education values",df['education'].unique())
print("Unique Default values",df['default'].unique())
print("Unique Housing values",df['housing'].unique())
print("Unique Loan values",df['loan'].unique())
print("Unique Month values",df['month'].unique())
print("Unique Campaign values",df['campaign'].unique())
print("Unique previous values",df['previous'].unique())
print("Unique y values",df['y'].unique())
# Out:
# Unique Marital values ['married' 'single' 'divorced']
# Unique Education values ['tertiary' 'secondary' 'primary']
# Unique Default values ['no' 'yes']
# Unique Housing values ['yes' 'no']
# Unique Loan values ['no' 'yes']
# Unique Month values ['may' 'jun' 'jul' 'aug' 'oct' 'nov' 'dec' 'jan' 'feb' 'mar' 'apr' 'sep']
# Unique Campaign values [ 1  2  3  5  4  7  8  6  9 10 11 12 13 19 14 24 16 32 18 22 15 17 25 21
#  43 51 41 26 28 55 50 38 23 20 29 31 37 30 46 27 58 33 35 34 36 39 44]
# Unique previous values [  0   3   1   4   2  11  16   6   5  10  12   7  18   9  21   8  14  15
#   26  37  13  25  20  27  17  23  38  29  24  51 275  22  19  30  58  28
#   32  40  55  35  41]
# Unique y values ['no' 'yes']

# %%
import seaborn as sns

# %%
sns.countplot(data=df,x='education')
plt.xlabel('\nEducation')
plt.ylabel('Count')
plt.title('Number people educated')
plt.show()

# %%
sns.countplot(data=df,x='marital')
plt.xlabel('\nMarital Status')
plt.ylabel('Count')
plt.title('Number people Married')
plt.show()

# %%
sns.countplot(data=df,x='housing')
plt.ylabel('Count')
plt.title('Number people Having Home')
plt.show()

# %%
df.rename(columns={'y': 'Subscribed'}, inplace=True)

# %%
sns.countplot(data=df,x='Subscribed')
plt.ylabel('Count')
plt.title('Number people Subscribed')
plt.show()

# %%
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   35    management  married   tertiary      no      231     yes   no
# 4   28    management   single   tertiary      no      447     yes  yes
#
#    day_of_week month  duration  campaign  pdays  previous Subscribed
# 0            5   may       261         1     -1         0         no
# 1            5   may       151         1     -1         0         no
# 2            5   may        76         1     -1         0         no
# 3            5   may       139         1     -1         0         no
# 4            5   may       217         1     -1         0         no

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.preprocessing import LabelEncoder

# %%
label_encoders = {}
for column in ['job', 'marital', 'education', 'default', 'housing', 'loan', 'month', 'Subscribed']:
    le = LabelEncoder()
    df[column] = le.fit_transform(df[column])
    label_encoders[column] = le

# %%
df.head()
# Out:
#    age  job  marital  education  default  balance  housing  loan  day_of_week  \
# 0   58    4        1          2        0     2143        1     0            5
# 1   44    9        2          1        0       29        1     0            5
# 2   33    2        1          1        0        2        1     1            5
# 3   35    4        1          2        0      231        1     0            5
# 4   28    4        2          2        0      447        1     1            5
#
#    month  duration  campaign  pdays  previous  Subscribed
# 0      8       261         1     -1         0           0
# 1      8       151         1     -1         0           0
# 2      8        76         1     -1         0           0
# 3      8       139         1     -1         0           0
# 4      8       217         1     -1         0           0

# %%
x = df.drop('Subscribed',axis=1)
y = df['Subscribed']

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
print("x train:",len(x_train))
print("x test:",len(x_test))
print("y train:",len(y_train))
print("y test:",len(y_test))
# Out:
# x train: 34554
# x test: 8639
# y train: 34554
# y test: 8639

# %%
clf = DecisionTreeClassifier()
clf.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = clf.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
report = classification_report(y_test, y_pred)

print(f'Accuracy: {accuracy:.2f}')
print('Classification Report:')
print(report)
# Out:
# Accuracy: 0.87
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.93      0.92      0.92      7658
#            1       0.42      0.42      0.42       981
#
#     accuracy                           0.87      8639
#    macro avg       0.67      0.67      0.67      8639
# weighted avg       0.87      0.87      0.87      8639
